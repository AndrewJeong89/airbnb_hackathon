# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_squared_error,r2_score
import matplotlib.pyplot as plt
plt.style.use('ggplot')
# %matplotlib inline

# %%
columns to use:
neighborhood
bedrooms
month

# %%
data_2015 = pd.read_csv('/Users/amishdalal/DSI-NYC-2/projects/projects-capstone/AirBnB/airbnb_data.csv',index_col=0)
data_2015.rename(columns = {'neighbourhood':'neighborhood'},inplace = True)
# data_2015.head()
# data_2015.to_csv('airbnb_data.csv')

# %%
# avg_occ = data_2015.groupby(['neighborhood','bedrooms','month'])['days_per_month','occupied'].sum()
# avg_occ.reset_index(inplace = True)
# avg_occ['occ_yr%'] = (100*(avg_occ['occupied'] / avg_occ['days_per_month'])).round(2)
# avg_occ.head()

# %%
# cols = ['month','bedrooms','number_of_reviews','review_scores_rating','neighborhood','num_comp','occ%','avg_price']
# data = data_2015.loc[:,cols]
# data['number_of_reviews'] = data['number_of_reviews'].astype(int)
# data['review_scores_rating'] = data['review_scores_rating'].astype(int)
# X = pd.get_dummies(data.iloc[:,:-1],columns = ['month','neighborhood'])
# y = data['avg_price']

# X_train,X_test,y_train,y_test = train_test_split(X,y, random_state = 25,test_size=0.33)
# gb = GradientBoostingRegressor(n_estimators=1000)
# gb = gb.fit(X_train,y_train)
# gb_pred = gb.predict(X_test)
# print mean_squared_error(y_test,gb_pred)
# print r2_score(y_test,gb_pred)

# %%
# gb_pred

# %%
# plt.subplots(figsize=(15,7))
# plt.scatter(gb_pred,y_test)
# plt.plot(y_test,y_test,'-',color='red')
# plt.show()

# plt.scatter(gb_pred,y_test-gb_pred)
# plt.show()

# %% [markdown]
# ### Relaxing the model by taking out num_comps and occupancy%

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import LabelEncoder


data_2015 = pd.read_csv('/Users/amishdalal/DSI-NYC-2/projects/projects-capstone/AirBnB/airbnb_data.csv',index_col=0)
data_2015.rename(columns = {'neighbourhood':'neighborhood'},inplace = True)
print data_2015.shape
cols = ['month','bedrooms','number_of_reviews','review_scores_rating','neighborhood','num_comp','occ%','avg_price']
data = data_2015.loc[:,cols]
le = LabelEncoder()

data['neighborhood'] = le.fit_transform(data['neighborhood'])
data['number_of_reviews'] = data['number_of_reviews'].astype(int)
data['review_scores_rating'] = data['review_scores_rating'].astype(int)
data['avg_price'] = data['avg_price'].astype(int)
data.to_csv('airbnb_model.csv')
X1 = data.iloc[:,:5]
y1 = data['avg_price']
X1_train,X1_test,y1_train,y1_test = train_test_split(X1,y1, random_state = 25,test_size=0.33)
gb1 = GradientBoostingRegressor(n_estimators=1000)
gb1 = gb1.fit(X1_train,y1_train)
gb1_pred = gb1.predict(X1_test)
print mean_squared_error(y1_test,gb1_pred)
print r2_score(y1_test,gb1_pred)
# Out:
# (47503, 20)
# 3062.35038479
# 0.679534843875

# %%
# import flask
# score = gb1.predict(np.array([5,4,100,80,5]))
# round(score,2)
# #results = {'Average Price': score}
# #results

# %%
#changing neighborhood to a labelencoder and setting a dataframe of neighborhood to its value
data_2015.loc[:,cols]
data_2015['neighborhood2'] = le.fit_transform(data_2015.loc[:,cols]['neighborhood'])
nhood_lookup = data_2015.loc[:,['neighborhood','neighborhood2']]
nhood_lookup.drop_duplicates(inplace = True)
nhood_lookup.sort_values('neighborhood2',inplace = True)
nhood_lookup.reset_index(inplace = True,drop=True)
nhood_lookup.to_json('neighborhood_value.json')
nhood_lookup.head()
d= {}
for nhood,value in zip(nhood_lookup['neighborhood'],nhood_lookup['neighborhood2']):
    #print nhood,value
    d[nhood] = value
# Out:
# 46

# %%
plt.subplots(figsize=(15,7))
plt.scatter(gb1_pred,y1_test)
plt.plot(y1_test,y1_test,'-',color='red')
plt.show()

plt.scatter(gb1_pred,y1_test-gb1_pred)
plt.show()

# %% [markdown]
# #### Bring in 2016 listings and calendar data. Get the Data into what is needed to run the model on

# %%
pd.read_json('/Users/amishdalal/DSI-NYC-2/projects/projects-capstone/AirBnB/abnb_cols_to_use.json')[0]
# Out:
# 0                         id
# 1                listing_url
# 2               last_scraped
# 3                       name
# 4          host_is_superhost
# 5                     street
# 6              neighbourhood
# 7                       area
# 8                    zipcode
# 9                   latitude
# 10                 longitude
# 11             property_type
# 12                 room_type
# 13              accommodates
# 14                 bathrooms
# 15                  bedrooms
# 16                      beds
# 17                  bed_type
# 18               square_feet
# 19                     price
# 20         number_of_reviews
# 21      review_scores_rating
# 22    review_scores_accuracy
# Name: 0, dtype: object

# %%
def listing_cleanup(path):
    """
    This function takes an airbnb listing and returns the columns that will be needed for merging later
    """
    listings = pd.read_csv(path)
    listings.rename(columns = {'neighbourhood_group_cleansed':'area'},inplace = True)
    
    cols_to_use = []
    for x in pd.read_json('/Users/amishdalal/DSI-NYC-2/projects/projects-capstone/AirBnB/abnb_cols_to_use.json')[0]:
        cols_to_use.append(x)
    cols_to_use.append('neighbourhood_cleansed')
    listings = listings.loc[:,cols_to_use]
    
    listings.rename(columns = {'neighbourhood':'neighborhood'},inplace = True)
    
    #converting price to int
    listings['price'] = listings['price'].apply(lambda x: x.replace('$','').replace(',','').replace('.00','')).astype(int)
    #only selecting non null bedrooms
    listings = listings[listings['bedrooms'].notnull()]
    #converting bedrooms to int
    listings['bedrooms'] = listings['bedrooms'].astype(int)
    #only selecting real beds
    listings = listings[listings['bed_type']=='Real Bed']
    
    #creating a groupby to get each listings avg price
    listings = listings.groupby(['id','neighborhood','zipcode','bedrooms','bathrooms','room_type',\
                          'number_of_reviews','review_scores_rating'])['price'].mean().to_frame()
    listings.reset_index(inplace = True)
    #ensuring that all neighborhoods are 
    nhood_area = pd.read_csv('/Users/amishdalal/DSI-NYC-2/projects/projects-capstone/AirBnB/neighbourhoods.csv')
    
    listings = pd.merge(listings,nhood_area,on=['neighborhood'])
    listings.rename(columns = {'id':'listing_id'},inplace = True)
    
    return listings

listings_16df = listing_cleanup('/Users/amishdalal/DSI-NYC-2/projects/projects-capstone/AirBnB/listings.csv')

# %%
# listings_2016 = pd.read_csv('/Users/amishdalal/DSI-NYC-2/projects/projects-capstone/AirBnB/listings.csv')
# listings_2016.rename(columns = {'neighbourhood_group_cleansed':'area'})
# cols_to_use = []
# for x in pd.read_json('/Users/amishdalal/DSI-NYC-2/projects/projects-capstone/AirBnB/abnb_cols_to_use.json')[0]:
#     cols_to_use.append(x)
# cols_to_use.append('neighbourhood_cleansed')
# listings_2016 = listings_2016.loc[:,cols_to_use]
# listings_2016['price'] = listings_2016['price'].apply(lambda x: x.replace('$','').replace(',','').replace('.00','')).astype(int)
# listings_2016 = listings_2016[listings_2016['bedrooms'].notnull()]
# listings_2016['bedrooms'] = listings_2016['bedrooms'].astype(int)
# listings_2016 = listings_2016[listings_2016['bed_type']=='Real Bed']

# listings_2016 = listings_2016.groupby(['id','neighbourhood','zipcode','bedrooms','bathrooms','room_type',\
#                           'number_of_reviews','review_scores_rating'])['price'].mean().to_frame()
# listings_2016.reset_index(inplace = True)


# zip_loc = pd.read_csv('/Users/amishdalal/DSI-NYC-2/projects/projects-capstone/zipcode_neighborhood.csv',index_col=0)
# nhood_area = zip_loc.groupby(['neighbourhood','area'])['zipcode'].count().to_frame('count')
# nhood_area.reset_index(inplace = True)
# del nhood_area['count']
# manhattan_nhoods = ['Flatiron District','Murray Hill','Alphabet City','Times Square','Noho','Midtown East','Gramercy Park',\
#                    'Chinatown','Greenwich Village','Nolita','Lower East Side','Union Square','Meatpacking District',\
#                     'Theatre District','Soho','Times Square/Theatre District','Yorkville','Morningside Heights']
# manhattan = []
# for x in manhattan_nhoods:
#     manhattan.append("Manhattan")
# manhattan_nhoodsdf = pd.DataFrame(manhattan_nhoods,columns = ['neighbourhood'])
# manhattan_df = pd.DataFrame(manhattan,columns = ['area'])
# nhood_area = nhood_area.append(pd.concat([manhattan_nhoodsdf,manhattan_df],axis=1))

# bk_nhoods = ['East Williamsburg','Prospect Heights','Boerum Hill','South Williamsburg','Downtown Brooklyn','DUMBO',]
# bk_area = []
# for x in bk_nhoods:
#     bk_area.append('Brooklyn')
# bk_nhoods_df = pd.DataFrame(bk_nhoods,columns = ['neighbourhood'])
# bk_areadf = pd.DataFrame(bk_area,columns = ['area'])
# nhood_area = nhood_area.append(pd.concat([bk_nhoods_df,bk_areadf],axis=1))

# nhood_area.reset_index(inplace = True,drop=True)
# nhood_area.to_csv('/Users/amishdalal/DSI-NYC-2/projects/projects-capstone/neighborhood_area.csv')

# %%
# print listings_2016.shape
# listings_16df = pd.merge(listings_2016,nhood_area,on=['neighbourhood'])
# listings_16df.rename(columns = {'id':'listing_id'},inplace = True)
# print listings_16df.shape
# Out:
# (24992, 9)
# (22120, 10)

# %%
def calendars(path,listings_df,occ_lower,occ_upper,review_limit):
    """
    This function takes the calendars that were aggregated from each csv file and merges with listings dataframe.
    Also filters out low/high occupancies, takes a minimum review number, filters out 5 or more bedrooms and shared rooms
    """
    cal_df = pd.read_csv(path,index_col=0)
    cal_df.rename(columns = {'neighbourhood':'neighborhood'},inplace = True)
    
    #merging with listings df
    cal_df = pd.merge(cal_df,listings_df)

    print 'Original DataFrame shape is:',cal_df.shape
    #dropping duplicates
    cal_df.drop_duplicates(inplace = True)
    print 'DataFrame after dropping duplicates is:',cal_df.shape
    
    #dropping any room types that are null, shared room or any bedrooms greater than 5 (only using 4 or less)
    
    cal_df1 = cal_df[(cal_df['room_type'].notnull()) & (cal_df['room_type']!='Shared room') & cal_df['bedrooms'] < 5]
    
    #because there are some that are inactive listings, that could be whole calendar is blocked (high yearly occupancy)
    #or low occupancy (very high price)
    
    #setting occupancy limits
    cal_df1 = cal_df[(cal_df['occ_yr%']<=occ_upper) & (cal_df['occ_yr%']>=occ_lower)]
    
    #setting min number of reviews to indicate activity
    print 'Min number of reviews in this dataframe is:',cal_df1['number_of_reviews'].min()
    cal_df2 = cal_df1[cal_df1['number_of_reviews']>=review_limit]
    
    return cal_df2
    

    
def one_br_split(df):
    """
    This function takes the calendar dataframe that is cleaned and returns only one bedroom listings
    """
    df = df[(df['bedrooms']==1)].copy()
    df['revpar'] = (df['avg_price'] * df['occ%']/100)
    
    return df

def entire_unit_split(df):
    occ_entire = df[(df['room_type']!='Private room')].copy()
    occ_entire['bedrooms'].value_counts()
    
    competitors = occ_entire.groupby(['zipcode','neighborhood','bedrooms'])['listing_id'].count().to_frame('num_comp')
    competitors.reset_index(inplace = True)

    occ_entire = pd.merge(occ_entire,competitors,on=['zipcode','neighborhood','bedrooms'])
    occ_entire = occ_entire[occ_entire['avg_price']!=0]  
    
    return occ_entire
    
path = '/Users/amishdalal/DSI-NYC-2/projects/projects-capstone/AirBnB/calendar_2016_agg_df_120716.csv'
occ16_1br_all = one_br_split(calendars(path,listings_16df,25,80,5))  
occ16_entire = entire_unit_split(calendars(path,listings_16df,25,80,5))
# Out:
# Original DataFrame shape is: (154380, 20)
# DataFrame after dropping duplicates is: (154380, 20)
# Min number of reviews in this dataframe is: 1
# Original DataFrame shape is: (154380, 20)
# DataFrame after dropping duplicates is: (154380, 20)
# Min number of reviews in this dataframe is: 1

# %%
def histograms(df):
    fig,axes = plt.subplots(2,2,figsize=(20,14))
    axes[0][0].hist(x = df[df['bedrooms']==1]['avg_price'],bins=20)
    axes[0][0].set_title("Distribution of Price for 1BR",fontsize = 18)
    axes[0][0].set_xlabel("Price",fontsize = 16)

    axes[0][1].hist(x=df[(df['bedrooms']==2)]['avg_price'],bins=20)
    axes[0][1].set_title('Distribution of Price for 2BR',fontsize=18)
    axes[0][1].set_xlabel('Price',fontsize=16)

    # & (occ_2015['avg_price']>=quantile_3br_25) & (occ_2015['avg_price']<=quantile_3br_75)
    axes[1][0].hist(x=df[(df['bedrooms']==3)]['avg_price'])
    axes[1][0].set_title('Distribution of Price for 3BR',fontsize=18)
    axes[1][0].set_xlabel('Price',fontsize=16)

    # & (occ_2015['avg_price']>=quantile_4br_25) & (occ_2015['avg_price']<=quantile_4br_75)
    axes[1][1].hist(x=df[(df['bedrooms']==4)]['avg_price'])
    axes[1][1].set_title('Distribution of Price for 4BR',fontsize=18)
    axes[1][1].set_xlabel('Price',fontsize=16)
    plt.show();
    return

# %%
#created a function, do not need this anymore
caldf16 = pd.read_csv('/Users/amishdalal/DSI-NYC-2/projects/projects-capstone/AirBnB/calendar_2016_agg_df_120716.csv',index_col=0)
df16 = pd.merge(caldf16,listings_16df)
print df16.shape

#dropping any duplicates after the merge
df16.drop_duplicates(inplace = True)
print 'Dataframe after dropping duplicates',df16.shape

occ16 = df16[(df16['room_type'].notnull()) & (df16['room_type']!='Shared room') & (df16['bedrooms'] < 5)]



# #there should not be places that are 'occupied' more than 80% on a yearly level. The number might be a little lower
# #but will weed out all places that are occuped by 80%. This might be that the room was blocked and not occupied by guests
occ16_limit = (occ16['occ_yr%']<=80) & (occ16['occ_yr%']>=25)
occ16 = occ16[occ16_limit]
# #lets also limit to listings with at least 5 review
num_reviews_limit = 0
occ16 = occ16[occ16['number_of_reviews']>num_reviews_limit]


occ16_1br_all = occ16[(occ16['bedrooms']==1)].copy()
occ16_1br_all['revpar'] = (occ16_1br_all['avg_price'] * occ16_1br_all['occ%']/100)
occ16_entire = occ16[(occ16['room_type']!='Private room')].copy()
occ16_entire['bedrooms'].value_counts()
#del occ16_entire['room_type']
competitors = occ16_entire.groupby(['zipcode','neighbourhood','bedrooms'])['listing_id'].count().to_frame('num_comp')
competitors.reset_index(inplace = True)

occ16_entire = pd.merge(occ16_entire,competitors,on=['zipcode','neighbourhood','bedrooms'])
occ16_entire = occ16_entire[occ16_entire['avg_price']!=0]
# Out:
# (158460, 19)
# Dataframe after dropping duplicates (152340, 19)

# %%
histograms(occ16_entire)

# %%
# #specifiying the price ranges of each bedroom to remove outliers
occ16_studio = occ16_entire[(occ16_entire['bedrooms']==0) & (occ16_entire['avg_price']>50) &
                               (occ16_entire['avg_price']<=350)]
occ16_1br = occ16_entire[(occ16_entire['bedrooms']==1) & (occ16_entire['avg_price']>50) &
                               (occ16_entire['avg_price']<=350)]
occ16_2br = occ16_entire[(occ16_entire['bedrooms']==2)& (occ16_entire['avg_price']>=85) &
                               (occ16_entire['avg_price']<600)]
occ16_3br = occ16_entire[(occ16_entire['bedrooms']==3) & (occ16_entire['avg_price']>=85) & \
                               (occ16_entire['avg_price']<=900)]
occ16_4br = occ16_entire[(occ16_entire['bedrooms']==4) & (occ16_entire['avg_price']>=100) &\
                               (occ16_entire['avg_price']<=1600) ]

occ16_1br = occ16_1br.append(occ16_studio)
occ_2016_1_2br = occ16_1br.append(occ16_2br)
occ_2016_3_4br = occ16_3br.append(occ16_4br)
data_2016 = occ_2016_1_2br.append(occ_2016_3_4br)
data_2016.reset_index(inplace = True,drop=True)
data_2016['revpar'] = (data_2016['avg_price'] * data_2016['occ%']/100)
print 'Removing outliers, the dataframe shape is',data_2016.shape
print data_2016['bedrooms'].value_counts()
print 'data_2016 shape is:',data_2016.shape
# Out:
# Removing outliers, the dataframe shape is (35647, 22)
# 1    18067
# 2     9501
# 0     4749
# 3     2717
# 4      613
# Name: bedrooms, dtype: int64
# data_2016 shape is: (35647, 22)

# %%
histograms(data_2016)

# %%
cols = ['month','bedrooms','number_of_reviews','review_scores_rating','neighborhood','num_comp','occ%','avg_price']
data16 = data_2016.loc[:,cols]  
#y = data16.loc[:,'avg_price']
data16['neighborhood2'] = le.fit_transform(data16['neighborhood'])
data16['review_scores_rating'] = data16['review_scores_rating'].astype(int)
data16.to_csv('airbnb_pricing_model_2016.csv')

neighborhood_key = data16.loc[:,['neighbourhood','neighborhood2']]
neighborhood_key.to_json('neighborhood_key_2016.json')
del data16['neighborhood'],data16['occ%'],data16['num_comp']
data_2016.rename(columns = {'neighbourhood2':'neighborhood'},inplace = True)



X2 = data16.iloc[:,[0,1,2,3,5]]
y2 = data16['avg_price']
print X2.shape, y2.shape
X2_train,X2_test,y2_train,y2_test = train_test_split(X2,y2, random_state = 25,test_size=0.33)
gb2 = GradientBoostingRegressor(n_estimators=1000)
gb2 = gb2.fit(X2_train,y2_train)
gb2_pred = gb2.predict(X2_test)
print mean_squared_error(y2_test,gb2_pred)
print r2_score(y2_test,gb2_pred)
# Out:
# (35647, 5) (35647,)
# 3900.20234315
# 0.699015520431

# %%
def neighborhood_price(df):
    nhood_price = df.groupby(['neighborhood','month','bedrooms','area','sub_area'])['avg_price'].agg([max,min,np.median,np.mean])
    nhood_price.reset_index(inplace = True)
    nhood_price['mean'] = nhood_price['mean'].round(0).astype(int)
    nhood_price['median'] = nhood_price['median'].round(0).astype(int)    
    nhood_price.rename(columns = {'max':'max_price','min':'min_price','median':'median_price','mean':'mean_price'},\
                      inplace = True)
    
    return nhood_price

nhood_price16 = neighborhood_price(data_2016)

# %%
    

# nhood_price16 = data_2016.groupby(['neighborhood','month','bedrooms'])['avg_price'].agg([max,min,np.median,np.mean])
# nhood_price16.reset_index(inplace = True)
# nhood_price16['mean'] = nhood_price16['mean'].round(0).astype(int)
# nhood_price16['median'] = nhood_price16['median'].round(0).astype(int)
# print nhood_price16.shape
# print data_2016.shape
# nhood_price16.head()
# neighborhoods = pd.read_csv('/Users/amishdalal/DSI-NYC-2/projects/projects-capstone/AirBnB/neighbourhoods.csv')
# neighborhoods.rename(columns = {'neighbourhood':'neighborhood'},inplace = True)
# nhood_price16 = pd.merge(nhood_price16,neighborhoods)
# Out:
# (2849, 7)
# (37463, 21)

# %%
month = int(raw_input('enter month'))
bedrooms = int(raw_input('enter bedrooms'))
# Out:
# enter month9
# enter bedrooms1

# %%
nhood_price16[(nhood_price16['month']==month) & (nhood_price16['bedrooms']==bedrooms)].sort_values('median_price')
nhood_price16.to_csv('neighborhood_prices_2016.csv')

# %%
pwd
# Out:
# u'/Users/amishdalal/airbnb_hackathon'

# %%
def listings_merge(df1,df2,listings_path):
    '''
    pass in the nhood_price df (average nhood prices) and the data df after price limits are entered.
    also need listings path to grab listing info such as address, zipcode, longitude, latitude, etc...
    '''
    df3 = pd.merge(df1,df2,on=['month','neighborhood','bedrooms','area','sub_area'])
    print df3.shape
    listing_cols = ['id','listing_url','latitude','longitude','zipcode','cleaning_fee','guests_included','instant_bookable','host_is_superhost']
    listings = pd.read_csv('/Users/amishdalal/DSI-NYC-2/projects/projects-capstone/AirBnB/listings.csv')
    listingdf = listings.loc[:,listing_cols]
    listingdf['instant_bookable'] = listingdf['instant_bookable'].apply(lambda x: 1 if x=='t' else 0)
    listingdf['host_is_superhost'] = listingdf['host_is_superhost'].apply(lambda x: 1 if x=='t' else 0)
    listingdf['cleaning_fee'] = listingdf['cleaning_fee'].apply(lambda x: str(x).replace('$','').replace(',','')).\
                astype(float)
    
    listingdf.rename(columns = {'id':'listing_id'},inplace = True)
    listing_agg = pd.merge(listingdf,df3,on=['listing_id','zipcode'])
    return listing_agg
path = '/Users/amishdalal/DSI-NYC-2/projects/projects-capstone/AirBnB/listings.csv'
listing_agg = listings_merge(data_2016,nhood_price16,path)
# Out:
# (35626, 26)

# %%
# df_16 =  pd.merge(data_2016,nhood_price16,on=['month','neighborhood','bedrooms','area'])
# print df_16.shape
# df_16[(df_16['month']==month) & (df_16['bedrooms']==bedrooms)]
# listing_cols = ['id','listing_url','latitude','longitude','zipcode','cleaning_fee','guests_included','instant_bookable','host_is_superhost']
# listingdf = listings.loc[:,listing_cols]
# listingdf['instant_bookable'] = listingdf['instant_bookable'].apply(lambda x: 1 if x=='t' else 0)
# listingdf['host_is_superhost'] = listingdf['host_is_superhost'].apply(lambda x: 1 if x=='t' else 0)
# listingdf['cleaning_fee'] = listingdf['cleaning_fee'].apply(lambda x: str(x).replace('$','').replace(',','')).\
#                 astype(float)
    
# listingdf.rename(columns = {'id':'listing_id'},inplace = True)
# listing_agg = pd.merge(listingdf,df_16,on=['listing_id','zipcode'])
# listing_agg
